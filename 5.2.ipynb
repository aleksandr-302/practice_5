# %%
def func(spisok):
  x1=0
  x2=0
  x3=0
  y1=0
  y2=0
  y3=0
  d1=0
  d2=0
  sqr = input() 
  spisok=[[int(sqr[0]), int(sqr[1]), int(sqr[2])], [int(sqr[3]), int(sqr[4]), int(sqr[5])], [int(sqr[6]), int(sqr[7]), int(sqr[8])]]
  print(spisok)
  for i in (0,3,6):
   y1=y1+int(sqr[i])

  for i in (1,4,7):
   y2=y2+int(sqr[i])

  for i in (2,5,8):
   y3=y3+int(sqr[i])

  for i in (0,1,2):
    x1=x1+int(sqr[i])

  for i in (3,4,5):
    x2=x2+int(sqr[i])

  for i in (6,7,8):
    x3=x3+int(sqr[i])

  for i in (0,4,8):
    d1=d1+int(sqr[i])

  for i in (2,4,6):
   d2=d2+int(sqr[i])

  if x1==x2 and x1==x3 and x1==y1 and x1==y2 and x1==y3 and x1==d1 and x1==d2:
   print("это магический квадрат")
  else:
    print("это не магический квадрат")

func(spisok)
# Out:
# 492357816
# [[4, 9, 2], [3, 5, 7], [8, 1, 6]]
# это магический квадрат
