# %%
stroka = input()
often = max([stroka.count(x) for x in stroka])
s = set(filter(lambda x: stroka.count(x) == often, stroka))
print('Символ встречающийся чаще всего: {}'. format(', '.join(sorted(list(s)))))
# Out:
# Небольшой текст
# Символ встречающийся чаще всего: е, о, т
