# %%
def func(spisok,n):
  spisok=input("введите список ")
  spisok=[int(c) for c in spisok]
  print(spisok)
  length=len(spisok)
  n=int(input("введите n "))
  print("числа большие n:")
  for i in range(0,length,1):
    if spisok[i]>n:
       print(spisok[i])

func(spisok,n)
# Out:
# введите список 123456789
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# введите n 6
# числа большие n:
# 7
# 8
# 9
